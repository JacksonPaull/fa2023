# %%
import matplotlib.pyplot as plt

modularity_data = [
    (156, 0.773),
    (122, 0.810),
    (91, 0.827),
    (58, 0.839),
    (44, 0.843),
    (37, 0.839),
    (30, 0.842),
    (28, 0.839),
    (25, 0.833),
    (23, 0.840),
    (20, 0.823),
    (14, 0.808),
    (12, 0.757),
    (6, 0.608),
    (1, 0.000)
]

# %%
fig, ax = plt.subplots()
ax.set_title('Problem 3 Part a)')
ax.set_xlabel('# Communities')
ax.set_ylabel('Modularity')


ax.plot([ i for i, j in modularity_data], 
         [j for i, j in modularity_data])
fig.savefig('./Problem3/Images/p3a.png')

# %% [markdown]
# # Problem 4

# %% [markdown]
# avg  path length - 11.758328926493919
#
# Average Clustering Coefficient: 0.026
#
# Total triangles: 1
#
# Average Degree: 2.032
